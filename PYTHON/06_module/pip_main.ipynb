# %%
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 8.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 4.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...

# %%
import numpy
import pandas

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.9.0
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.6.15
# cffi                      1.17.1
# charset-normalizer        3.4.2
# comm                      0.2.2
# debugpy                   1.8.14
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.29.5
# ...

# %% [markdown]
# ### 현재 내 환경에 설치 되어 있는 라이브러리들을 requirements.txt에 저장하는 명령어
# - 내 환경을 다른 작업자에게 넘길 때 같이 주면 좋음!

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# ### requirements.txt 텍스트 파일에 있는 라이브러리들 모두 설치하는 명령어
# - 넘겨 받은 환경을 내 컴퓨터에 설치!

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# ...
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl.metadata (6.7 kB)
# ...
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# ...
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# ...
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached cffi-1.17.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.5 kB)
# ...
#   Using cached charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# ...
#   Using cached debugpy-1.8.14-cp312-cp312-macosx_14_0_universal2.whl.metadata (1.3 kB)
# ...
