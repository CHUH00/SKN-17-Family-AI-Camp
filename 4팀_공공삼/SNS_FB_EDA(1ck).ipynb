# %% [markdown]
# ### 라이브러리 임포트

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 전처리

# %% [markdown]
# ### 21년도

# %%
df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p21v31_KMP_csv.csv', encoding='CP949')

feature = ['pid', 'p21age', 'p21gender', 'p21school', 'p21mar', 'p21job1', 'p21income', 'p21relig1', 'p21d27001', 'p21d27002', 'p21d27003', 'p21d27004', 'p21d11002']

df_21 = df[feature].copy()

df_21.rename(
    columns={
        'p21age': 'age', 
        'p21gender': 'gender', 
        'p21school': 'school', 
        'p21mar': 'mar', 
        'p21job1': 'job1', 
        'p21income': 'income', 
        'p21relig1': 'relig1', 
        'p21d27001': 'd01', 
        'p21d27002': 'd02', 
        'p21d27003': 'd03', 
        'p21d27004': 'd04',
        'p21d11002': 'label'
    }, inplace=True
)

df_21['year'] = 2021

df_21.head()
# Out:
# /var/folders/l_/jwxy6nr92x313h1886h_krpm0000gn/T/ipykernel_98493/1276130766.py:1: DtypeWarning: Columns (5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p21v31_KMP_csv.csv', encoding='CP949')
#      pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03 d04  \
# 0  10001    6       1       5    2     1       7       1   6   7   6   6
# 1  10002    5       2       5    2     2       1       1   4   4   4   4
# 2  10003    3       2       5    1     1       5       1   1   4   7   1
# 3  10004    3       1       5    1     2       1       1   1   3   4   3
# 4  20001    6       1       5    2     1       6       1   4   5   5   4
#
#   label  year
# 0     1  2021
# 1    12  2021
# 2     2  2021
# 3     1  2021
# 4    12  2021

# %% [markdown]
# ### 22년도

# %%
df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p22v31_KMP_csv.csv', encoding='CP949')

feature = ['pid', 'p22age', 'p22gender', 'p22school', 'p22mar', 'p22job1', 'p22income', 'p22relig1', 'p22d27001', 'p22d27002', 'p22d27003', 'p22d27004', 'p22d11002']

df_22 = df[feature].copy()

df_22.rename(
    columns={
        'p22age': 'age', 
        'p22gender': 'gender', 
        'p22school': 'school', 
        'p22mar': 'mar', 
        'p22job1': 'job1', 
        'p22income': 'income', 
        'p22relig1': 'relig1', 
        'p22d27001': 'd01', 
        'p22d27002': 'd02', 
        'p22d27003': 'd03', 
        'p22d27004': 'd04',
        'p22d11002': 'label'
    }, inplace=True
)

df_22['year'] = 2022

df_22.head()
# Out:
# /var/folders/l_/jwxy6nr92x313h1886h_krpm0000gn/T/ipykernel_98493/4120115928.py:1: DtypeWarning: Columns (5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p22v31_KMP_csv.csv', encoding='CP949')
#      pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03 d04  \
# 0  10001    6       1       5    2     1       6       1   3   5   5   4
# 1  10002    6       2       5    2     2       1       1  11   5   5   5
# 2  10003    3       2       5    1     1       5       2   9   4   7  10
# 3  10004    3       1       5    1     2       1       2  11   6   5   6
# 4  20001    6       1       5    2     1       6       2   4   4   4   4
#
#   label  year
# 0     1  2022
# 1    15  2022
# 2     2  2022
# 3    15  2022
# 4     1  2022

# %% [markdown]
# ### 23년도

# %%
df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p23v31_KMP_csv.csv', encoding='CP949')

feature = ['pid', 'p23age', 'p23gender', 'p23school', 'p23mar', 'p23job1', 'p23income', 'p23relig1', 'p23d27001', 'p23d27002', 'p23d27003', 'p23d27004', 'p23d11002']

df_23 = df[feature].copy()

df_23.rename(
    columns={
        'p23age': 'age', 
        'p23gender': 'gender', 
        'p23school': 'school', 
        'p23mar': 'mar', 
        'p23job1': 'job1', 
        'p23income': 'income', 
        'p23relig1': 'relig1', 
        'p23d27001': 'd01', 
        'p23d27002': 'd02', 
        'p23d27003': 'd03', 
        'p23d27004': 'd04',
        'p23d11002': 'label'
    }, inplace=True
)

df_23['year'] = 2023

df_23.head()
# Out:
# /var/folders/l_/jwxy6nr92x313h1886h_krpm0000gn/T/ipykernel_98493/3582034847.py:1: DtypeWarning: Columns (5,8,9,511) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p23v31_KMP_csv.csv', encoding='CP949')
#      pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03 d04  \
# 0  10001    6       1       5    2     1       6       2   5   6   7   5
# 1  10002    6       2       5    2     2       1       2   6   7   7   6
# 2  10003    3       2       5    1     1       5       2   3   4   4   5
# 3  10004    3       1       5    1     2       1       2   5   7   6   5
# 4  20001    6       1       5    2     1       7       2   5   9   5   6
#
#   label  year
# 0     2  2023
# 1     2  2023
# 2     2  2023
# 3    24  2023
# 4     2  2023

# %% [markdown]
# ### 24년도

# %%
df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p24v31_KMP_csv.csv', encoding='CP949')

feature = ['pid', 'p24age', 'p24gender', 'p24school', 'p24mar', 'p24job1', 'p24income', 'p24relig1', 'p24d27001', 'p24d27002', 'p24d27003', 'p24d27004', 'p24d11002']

df_24 = df[feature].copy()

df_24.rename(
    columns={
        'p24age': 'age', 
        'p24gender': 'gender', 
        'p24school': 'school', 
        'p24mar': 'mar', 
        'p24job1': 'job1', 
        'p24income': 'income', 
        'p24relig1': 'relig1', 
        'p24d27001': 'd01', 
        'p24d27002': 'd02', 
        'p24d27003': 'd03', 
        'p24d27004': 'd04',
        'p24d11002': 'label'
    }, inplace=True
)

df_24['year'] = 2024

df_24.head()
# Out:
# /var/folders/l_/jwxy6nr92x313h1886h_krpm0000gn/T/ipykernel_98493/2118142143.py:1: DtypeWarning: Columns (5,8,9,295,296,297,298,299,300,371,372,373,374) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/woojin/Desktop/SK Networks Family AI Camp_17/4팀_공공삼/data/p24v31_KMP_csv.csv', encoding='CP949')
#      pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03 d04  \
# 0  10002    6       2       5    2     2       1       2  11   5   4   5
# 1  10003    3       2       5    1     1       5       2  11   4  12   3
# 2  10004    3       1       5    1     1       5       2   3   4   3   4
# 3  20001    6       1       5    1     1       5       1  11   3  12   4
# 4  20003    4       1       5    1     1       5       2  11   4   3   5
#
#   label  year
# 0    16  2024
# 1    15  2024
# 2     2  2024
# 3     2  2024
# 4     2  2024

# %%
df_all = pd.concat([df_21, df_22, df_23, df_24], ignore_index=True)
df_all

df_all = df_all.sort_values(by=['pid', 'year']).reset_index(drop=True)
df_all
# Out:
#              pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03  \
# 0          10001    6       1       5    2     1       7       1   6   7   6
# 1          10001    6       1       5    2     1       6       1   3   5   5
# 2          10001    6       1       5    2     1       6       2   5   6   7
# 3          10002    5       2       5    2     2       1       1   4   4   4
# 4          10002    6       2       5    2     2       1       1  11   5   5
# ...          ...  ...     ...     ...  ...   ...     ...     ...  ..  ..  ..
# 38540  118320001    8       2       2    3     2       3       1
# 38541  118330001    8       2       2    3     2       3       2
# 38542  118330001    8       2       2    3     1       3       2
# 38543  118330001    8       2       2    3     1       3       1
# 38544  118330001    8       2       2    3     2       3       1
#
#       d04 label  year
# 0       6     1  2021
# 1       4     1  2022
# 2       5     2  2023
# 3       4    12  2021
# 4       5    15  2022
# ...    ..   ...   ...
# 38540            2024
# 38541            2021
# 38542            2022
# 38543            2023
# 38544            2024
#
# [38545 rows x 14 columns]

# %% [markdown]
# ### 결측치 제거

# %%
df_all = df_all[df_all['label'].str.strip() != ''].reset_index(drop=True)

# %%
# 2. 각 pid 그룹 내에서 다음 연도의 label 값을 가져옵니다.
df_all['next_year_label'] = df_all.groupby('pid')['label'].shift(-1)
df_all
# Out:
#              pid  age  gender  school  mar  job1  income  relig1 d01 d02 d03  \
# 0          10001    6       1       5    2     1       7       1   6   7   6
# 1          10001    6       1       5    2     1       6       1   3   5   5
# 2          10001    6       1       5    2     1       6       2   5   6   7
# 3          10002    5       2       5    2     2       1       1   4   4   4
# 4          10002    6       2       5    2     2       1       1  11   5   5
# ...          ...  ...     ...     ...  ...   ...     ...     ...  ..  ..  ..
# 20735  118290002    5       1       5    2     1       5       2   7   9   7
# 20736  118300001    3       1       4    1     1       5       1   3   9   9
# 20737  118300001    3       1       4    1     1       5       2   3   9   9
# 20738  118300001    3       1       4    1     1       5       2   3   9   9
# 20739  118300001    3       1       4    1     1       5       2   3   9   9
#
#       d04 label  year next_year_label
# 0       6     1  2021               1
# 1       4     1  2022               2
# 2       5     2  2023             NaN
# 3       4    12  2021              15
# 4       5    15  2022               2
# ...    ..   ...   ...             ...
# 20735   7    16  2024             NaN
# 20736   9     2  2021              15
# 20737   9    15  2022              15
# 20738   9    15  2023              15
# 20739   9    15  2024             NaN
#
# [20740 rows x 15 columns]

# %%
# 3. 이탈(churn) 여부를 정의합니다.
# 조건 1: 현재 레이블이 2이고 (df_all['label'] == 2)
# 조건 2: 다음 해의 레이블이 존재하며 2가 아닌 경우 (df_all['next_year_label'].notna() & (df_all['next_year_label'] != 2))
# 위 두 조건을 만족하면 이탈(1), 아니면 비이탈(0)로 정의합니다.
churn_conditions = [
    (df_all['label'] == '2') & (df_all['next_year_label'].notna()) & (df_all['next_year_label'] != '2'),
    (df_all['label'] == '2') & (df_all['next_year_label'].notna()) & (df_all['next_year_label'] == '2')
]
churn_choices = [1, 0] # 1: 이탈 (Churn), 0: 비이탈 (Not Churn)

df_all['churn'] = np.select(churn_conditions, churn_choices, default=np.nan)

# %%
# 4. 분석에 사용할 데이터셋을 생성합니다.
# 'churn' 값이 NaN이 아닌 경우, 즉 현재 label이 2인 고객들의 데이터만 필터링합니다.
# 이 데이터셋이 EDA와 모델링의 기반이 됩니다.
df_model_base = df_all[df_all['churn'].notna()].copy()

# 불필요해진 'next_year_label' 컬럼 삭제
df_model_base.drop(columns=['next_year_label'], inplace=True)

df_model_base['churn'] = df_model_base['churn'].astype(int)

# %%
mapping = {
    '1': 11,  # 하루에도 여러 번 → 빈도 가장 높음
    '2': 10,  # 하루 1번(매일)
    '3': 9,   # 하루 5회 이상
    '4': 8,  # 하루 3~4회
    '5': 7,  # 하루 1~2회
    '6': 6,   # 1주일에 5~6회
    '7': 5,   # 1주일에 3~4회
    '8': 4,   # 1주일에 1~2회 정도
    '9': 3,   # 월 1~3회
    '10': 2,   # 월 1회 미만
    '11': 1    # 분기/연간 1회 정도 → 빈도 가장 낮음
}

df_model_base['d01'] = df_model_base['d01'].map(mapping).fillna(0).astype(int)
df_model_base['d02'] = df_model_base['d02'].map(mapping).fillna(0).astype(int)
df_model_base['d03'] = df_model_base['d03'].map(mapping).fillna(0).astype(int)
df_model_base['d04'] = df_model_base['d04'].map(mapping).fillna(0).astype(int)

# %%
print("이탈 예측을 위한 기본 데이터셋:")
print(df_model_base.head())
print("\n전체 이탈율:")
print(df_model_base['churn'].value_counts(normalize=True))
# Out:
# 이탈 예측을 위한 기본 데이터셋:
#       pid  age  gender  school  mar  job1  income  relig1  d01  d02  d03  d04  \
# 5   10002    6       2       5    2     2       1       2    6    5    5    6
# 7   10003    3       2       5    1     1       5       1   11    8    5   11
# 8   10003    3       2       5    1     1       5       2    3    8    5    2
# 9   10003    3       2       5    1     1       5       2    9    8    8    7
# 17  20001    6       1       5    2     1       7       2    7    3    7    6
#
#    label  year  churn
# 5      2  2023      1
# 7      2  2021      0
# 8      2  2022      0
# 9      2  2023      1
# 17     2  2023      0
#
# 전체 이탈율:
# churn
# 0    0.507454
# 1    0.492546
# Name: proportion, dtype: float64

# %% [markdown]
# ### EDA

# %%
# 한글 폰트 사용을 위한 설정
import matplotlib.font_manager as fm
import matplotlib

font_path = '/System/Library/Fonts/AppleSDGothicNeo.ttc'
font = fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font)

# --- 2. 인구통계학적 특성 분석 ---
print("--- 1. 인구통계학적 특성 분석 (df_model_base 대상) ---")
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('인구통계학적 특성에 따른 이탈 분석', fontsize=16)

# 성별(gender)에 따른 이탈 분석
gender_churn = pd.crosstab(df_model_base['gender'], df_model_base['churn'], normalize='index')
print("\n성별에 따른 이탈률:\n", gender_churn)
sns.barplot(data=gender_churn.reset_index(), x='gender', y=1, ax=axes[0])
axes[0].set_title('성별에 따른 이탈률 (1: 남성, 2: 여성)')
axes[0].set_ylabel('이탈률(Churn Rate)')
axes[0].set_ylim(0, 1)

# 연령대(age)에 따른 이탈 분석
age_churn = pd.crosstab(df_model_base['age'], df_model_base['churn'], normalize='index')
print("\n연령대에 따른 이탈률:\n", age_churn)
sns.barplot(data=age_churn.reset_index(), x='age', y=1, ax=axes[1])
axes[1].set_title('연령대에 따른 이탈률')
axes[1].set_ylabel('이탈률(Churn Rate)')
axes[1].set_ylim(0, 1)

# 결혼상태(mar)에 따른 이탈 분석
mar_churn = pd.crosstab(df_model_base['mar'], df_model_base['churn'], normalize='index')
print("\n결혼상태에 따른 이탈률:\n", mar_churn)
sns.barplot(data=mar_churn.reset_index(), x='mar', y=1, ax=axes[2])
axes[2].set_title('결혼상태에 따른 이탈률')
axes[2].set_ylabel('이탈률(Churn Rate)')
axes[2].set_ylim(0, 1)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# --- 1. 인구통계학적 특성 분석 (df_model_base 대상) ---
#
# 성별에 따른 이탈률:
#  churn          0         1
# gender
# 1       0.520742  0.479258
# 2       0.490722  0.509278
#
# 연령대에 따른 이탈률:
#  churn         0         1
# age
# 1      0.000000  1.000000
# 2      0.427686  0.572314
# 3      0.457064  0.542936
# 4      0.484513  0.515487
# 5      0.546089  0.453911
# 6      0.582482  0.417518
# 7      0.563380  0.436620
# 8      0.142857  0.857143
#
# 결혼상태에 따른 이탈률:
#  churn         0         1
# mar
# 1      0.459392  0.540608
# 2      0.557776  0.442224
# 3      0.545455  0.454545
# 4      0.431373  0.568627

# %%
# --- 3. 사회경제적 특성 분석 ---
print("\n--- 2. 사회경제적 특성 분석 (df_model_base 대상) ---")
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle('사회경제적 특성에 따른 이탈 분석', fontsize=16)

# 직업(job1)에 따른 이탈 분석
job_churn = pd.crosstab(df_model_base['job1'], df_model_base['churn'], normalize='index')
print("\n직업에 따른 이탈률:\n", job_churn)
sns.barplot(data=job_churn.reset_index(), x='job1', y=1, ax=axes[0])
axes[0].set_title('직업에 따른 이탈률')
axes[0].set_ylabel('이탈률(Churn Rate)')
axes[0].set_ylim(0, 1)

# 소득(income)에 따른 이탈 분석
income_churn = pd.crosstab(df_model_base['income'], df_model_base['churn'], normalize='index')
print("\n소득수준에 따른 이탈률:\n", income_churn)
sns.barplot(data=income_churn.reset_index(), x='income', y=1, ax=axes[1])
axes[1].set_title('소득수준에 따른 이탈률')
axes[1].set_ylabel('이탈률(Churn Rate)')
axes[1].set_ylim(0, 1)

# 종교(relig1)에 따른 이탈 분석
relig_churn = pd.crosstab(df_model_base['relig1'], df_model_base['churn'], normalize='index')
print("\n종교에 따른 이탈률:\n", relig_churn)
sns.barplot(data=relig_churn.reset_index(), x='relig1', y=1, ax=axes[2])
axes[2].set_title('종교에 따른 이탈률')
axes[2].set_ylabel('이탈률(Churn Rate)')
axes[2].set_ylim(0, 1)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# --- 2. 사회경제적 특성 분석 (df_model_base 대상) ---
#
# 직업에 따른 이탈률:
#  churn         0         1
# job1
# 1      0.538685  0.461315
# 2      0.454471  0.545529
#
# 소득수준에 따른 이탈률:
#  churn          0         1
# income
# 1       0.456844  0.543156
# 2       0.260870  0.739130
# 3       0.479452  0.520548
# 4       0.555556  0.444444
# 5       0.526807  0.473193
# 6       0.531993  0.468007
# 7       0.528736  0.471264
# 8       0.616352  0.383648
#
# 종교에 따른 이탈률:
#  churn          0         1
# relig1
# 1       0.526702  0.473298
# 2       0.499571  0.500429

# %%
# --- 4. 서비스 만족도 관련 특성 분석 ---
print("\n--- 3. 서비스 만족도 관련 특성 분석 (df_model_base 대상) ---")
satisfaction_cols = ['d01', 'd02', 'd03', 'd04']
satisfaction_churn = df_model_base.groupby('churn')[satisfaction_cols].mean()
print("\n이탈 여부에 따른 만족도 평균:\n", satisfaction_churn)

plt.figure(figsize=(8, 4))
sns.heatmap(satisfaction_churn.T, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('이탈 여부에 따른 만족도 관련 특성 평균 비교')
plt.xlabel('Churn (0: 비이탈, 1: 이탈)')
plt.ylabel('만족도 특성')
plt.show()
# Out:
# --- 3. 서비스 만족도 관련 특성 분석 (df_model_base 대상) ---
#
# 이탈 여부에 따른 만족도 평균:
#              d01       d02       d03       d04
# churn
# 0      6.056355  5.436451  5.359113  5.351319
# 1      6.054355  5.504015  5.373070  5.273626

# %% [markdown]
# ### 딥러닝 준비

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 1. 특성(X)과 타겟(y) 분리
# pid, year 등 모델링에 직접 사용하지 않을 컬럼은 제외합니다.
X = df_model_base.drop(columns=['pid', 'year', 'label', 'churn'])
y = df_model_base['churn']

# 2. 범주형 변수 원-핫 인코딩 (One-Hot Encoding)
# income, school 등 범주형 변수들을 더미 변수로 변환합니다.
X = pd.get_dummies(X, columns=['gender', 'school', 'mar', 'job1', 'income', 'relig1'], drop_first=True)

# 3. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 4. 학습 및 테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
# df_model_base['satisfaction_score'] = df_model_base[['d01', 'd02', 'd03', 'd04']].sum(axis=1) / 4
# df_model_base[['d01','d02','d03','d04','satisfaction_score']]
# Out:
#        d01  d02  d03  d04  satisfaction_score
# 5        6    5    5    6                5.50
# 7       11    8    5   11                8.75
# 8        3    8    5    2                4.50
# 9        9    8    8    7                8.00
# 17       7    3    7    6                5.75
# ...    ...  ...  ...  ...                 ...
# 20640    1    6    6    7                5.00
# 20653    9    5    5    5                6.00
# 20654    1    3    3    3                2.50
# 20715   10    3    7    5                6.25
# 20736    9    3    3    3                4.50
#
# [3287 rows x 5 columns]

# %%
# plt.figure(figsize=(18, 5))
# plt.title('사회경제적 특성에 따른 이탈 분석', fontsize=16)

# # 종교(relig1)에 따른 이탈 분석
# relig_churn = pd.crosstab(df_model_base['satisfaction_score'], df_model_base['churn'], normalize='index')
# print("\n종교에 따른 이탈률:\n", relig_churn)
# sns.barplot(data=relig_churn.reset_index(), x='satisfaction_score', y=1)
# plt.ylabel('이탈률(Churn Rate)')
# plt.ylim(0, 1)

# plt.tight_layout(rect=[0, 0.03, 1, 0.95])
# plt.show()
# Out:
# 종교에 따른 이탈률:
#  churn                      0         1
# satisfaction_score
# 0.25                0.656250  0.343750
# 0.50                0.533333  0.466667
# 0.75                0.350000  0.650000
# 1.00                0.538462  0.461538
# 1.25                0.428571  0.571429
# 1.50                0.750000  0.250000
# 1.75                0.375000  0.625000
# 2.00                0.357143  0.642857
# 2.25                0.666667  0.333333
# 2.50                0.548387  0.451613
# 2.75                0.371429  0.628571
# 3.00                0.414634  0.585366
# 3.25                0.608696  0.391304
# 3.50                0.564815  0.435185
# 3.75                0.580645  0.419355
# 4.00                0.500000  0.500000
# 4.25                0.508876  0.491124
# 4.50                0.504274  0.495726
# 4.75                0.519084  0.480916
# 5.00                0.430000  0.570000
# 5.25                0.446281  0.553719
# 5.50                0.330935  0.669065
# 5.75                0.520833  0.479167
# 6.00                0.495690  0.504310
# 6.25                0.521739  0.478261
# 6.50                0.520000  0.480000
# 6.75                0.496350  0.503650
# 7.00                0.527027  0.472973
# 7.25                0.490196  0.509804
# 7.50                0.592593  0.407407
# 7.75                0.450000  0.550000
# 8.00                0.468750  0.531250
# 8.25                0.384615  0.615385
# 8.50                0.457143  0.542857
# 8.75                0.566667  0.433333
# 9.00                0.600000  0.400000
# 9.25                0.727273  0.272727
# 9.50                0.464286  0.535714
# 9.75                0.750000  0.250000
# 10.00               0.654545  0.345455
# 10.25               0.631579  0.368421
# 10.50               1.000000  0.000000
# 10.75               0.000000  1.000000
# 11.00               0.519231  0.480769

# %%
# df_model_base['income']과 df_model_base['job1'] 컬럼의 데이터 타입을 문자열로 변환합니다.
# 이렇게 하면 두 컬럼의 값들을 안정적으로 결합할 수 있습니다.
df_model_base['income_job_combo'] = df_model_base['income'].astype(str) + '_' + df_model_base['job1'].astype(str)

# 새로 생성된 컬럼의 상위 5개 행을 출력하여 변수가 잘 생성되었는지 확인합니다.
print("파생변수 추가 후 데이터프레임:")
print(df_model_base[['income', 'job1', 'income_job_combo']].head())

# 새로 생성된 파생변수의 범주별 개수를 확인합니다.
print("\n'income_job_combo'의 범주별 개수:")
df_model_base['income_job_combo'].value_counts()
# Out:
# 파생변수 추가 후 데이터프레임:
#     income  job1 income_job_combo
# 5        1     2              1_2
# 7        5     1              5_1
# 8        5     1              5_1
# 9        5     1              5_1
# 17       7     1              7_1
#
# 'income_job_combo'의 범주별 개수:
# income_job_combo
# 1_2    1130
# 5_1     850
# 6_1     546
# 4_1     291
# 7_1     172
# 8_1     159
# 3_2      42
# 3_1      31
# 2_2      21
# 1_1      17
# 4_2      15
# 5_2       8
# 7_2       2
# 2_1       2
# 6_2       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18, 5))
plt.title('사회경제적 특성에 따른 이탈 분석', fontsize=16)

# 종교(relig1)에 따른 이탈 분석
relig_churn = pd.crosstab(df_model_base['income_job_combo'], df_model_base['churn'], normalize='index')
print("\n종교에 따른 이탈률:\n", relig_churn)
sns.barplot(data=relig_churn.reset_index(), x='income_job_combo', y=1)
plt.ylabel('이탈률(Churn Rate)')
plt.ylim(0, 1)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# 종교에 따른 이탈률:
#  churn                    0         1
# income_job_combo
# 1_1               0.588235  0.411765
# 1_2               0.454867  0.545133
# 2_1               0.000000  1.000000
# 2_2               0.285714  0.714286
# 3_1               0.516129  0.483871
# 3_2               0.452381  0.547619
# 4_1               0.553265  0.446735
# 4_2               0.600000  0.400000
# 5_1               0.524706  0.475294
# 5_2               0.750000  0.250000
# 6_1               0.532967  0.467033
# 6_2               0.000000  1.000000
# 7_1               0.534884  0.465116
# 7_2               0.000000  1.000000
# 8_1               0.616352  0.383648
